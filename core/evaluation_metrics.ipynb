# %%
import wandb
api = wandb.Api()
run = api.run("/ben-alaya-ma/repaint/runs/2024_06_02_16_41_47_534205")
print(run.history())
# Out:
#                                      repaint/Example_  \
# 0   {'count': 1, 'filenames': ['media/images/repai...
# 1   {'filenames': ['media/images/repaint/Example__...
# 2   {'_type': 'images/separated', 'format': 'png',...
# 3   {'_type': 'images/separated', 'format': 'png',...
# 4   {'filenames': ['media/images/repaint/Example__...
# 5   {'filenames': ['media/images/repaint/Example__...
# 6   {'filenames': ['media/images/repaint/Example__...
# 7   {'filenames': ['media/images/repaint/Example__...
# 8   {'width': 128, 'count': 1, 'filenames': ['medi...
# 9   {'height': 512, 'width': 128, 'count': 1, 'fil...
# 10  {'filenames': ['media/images/repaint/Example__...
# 11  {'format': 'png', 'height': 512, 'width': 128,...
# 12  {'filenames': ['media/images/repaint/Example__...
# 13  {'filenames': ['media/images/repaint/Example__...
# 14  {'filenames': ['media/images/repaint/Example__...
# 15  {'format': 'png', 'height': 512, 'width': 128,...
# ...
